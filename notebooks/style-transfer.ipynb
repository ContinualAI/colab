# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/saicodes/Style-Transfer-on-google-colab/blob/master/MinorProject.ipynb)

# %%
# !rm -r ComputerVision NeuralStyleTransfer

# !git clone https://github.com/ldfrancis/ComputerVision.git
  
# !cp -r ComputerVision/NeuralStyleTransfer .
# Out:
# Cloning into 'ComputerVision'...
# remote: Enumerating objects: 540, done.
# remote: Total 540 (delta 0), reused 0 (delta 0), pack-reused 540
# Receiving objects: 100% (540/540), 32.07 MiB | 27.30 MiB/s, done.
# Resolving deltas: 100% (245/245), done.

# %%
% load https://github.com/ldfrancis/ComputerVision/blob/master/NeuralStyleTransfer/implementNTS.py

# %%
from google.colab import files
files.upload()

# %%
CONTENT_IMAGE = "content1.jpg" 
STYLE_IMAGE = "style1.jpg"

IMAGE_HEIGHT = 300
IMAGE_WIDTH = 400

ITERATION = 200

# %%
path_to_content_image = "/content/"+CONTENT_IMAGE
path_to_style_image = "/content/"+STYLE_IMAGE

# %%
import matplotlib.pyplot as plt
c_image = plt.imread(path_to_content_image)
s_image = plt.imread(path_to_style_image)

# %%
print("Content Image of size (height, width) => {0}".format(c_image.shape[:-1]))
plt.imshow(c_image)
# Out:
# Content Image of size (height, width) => (251, 201)

# %%
print("Style Image of size (height, width) => {0}".format(s_image.shape[:-1]))
plt.imshow(s_image)
# Out:
# Style Image of size (height, width) => (258, 195)

# %%
from NeuralStyleTransfer import implementNTS as NST

# %%
NST.setImageDim(IMAGE_WIDTH,IMAGE_HEIGHT)

# %%
NST.run(ITERATION, style_image=path_to_style_image, content_image=path_to_content_image)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Iteration 20 :
# total cost = 76973640000.0
# content cost = 17403.484
# style cost = 753325600.0
# total variational loss =  8204751.0
# Time elapsed:  87.85310316085815
# Iteration 40 :
# total cost = 28600277000.0
# content cost = 18535.254
# style cost = 268721500.0
# total variational loss =  8639936.0
# Time elapsed:  83.01148223876953
# Iteration 60 :
# total cost = 15361868000.0
# content cost = 18703.346
# style cost = 136811600.0
# total variational loss =  8402834.0
# Time elapsed:  87.15378165245056
# Iteration 80 :
# total cost = 10510574000.0
# content cost = 19005.914
# style cost = 89065896.0
# total variational loss =  8019212.5
# Time elapsed:  84.9556999206543
# Iteration 100 :
# total cost = 8067141000.0
# content cost = 19324.184
# style cost = 65459104.0
# total variational loss =  7605430.5
# Time elapsed:  83.69147229194641
# Iteration 120 :
# total cost = 6553433000.0
# content cost = 19608.102
# style cost = 51126070.0
# total variational loss =  7203395.0
# Time elapsed:  100.81869554519653
# Iteration 140 :
# total cost = 5502177300.0
# content cost = 19857.662
# style cost = 41369120.0
# total variational loss =  6825583.0
# Time elapsed:  153.5166130065918
# Iteration 160 :
# total cost = 4727787000.0
# content cost = 20082.016
# style cost = 34327356.0
# total variational loss =  6474505.0
# Time elapsed:  83.45742726325989
# Iteration 180 :
# total cost = 4128590800.0
# content cost = 20291.596
# style cost = 28983156.0
# total variational loss =  6150615.5
# Time elapsed:  99.76709008216858
# Iteration 200 :
# total cost = 3650144300.0
# content cost = 20476.607
# style cost = 24792082.0
# total variational loss =  5853911.5
# Time elapsed:  130.78316450119019

# %%
generated_image_path = "/content/NeuralStyleTransfer/output/generated_image.jpg"
image = plt.imread(generated_image_path)
plt.imshow(image)

# %%
files.download("NeuralStyleTransfer/output/generated_image.jpg")
